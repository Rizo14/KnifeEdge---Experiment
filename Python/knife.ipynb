# %%
import serial
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import elliptec

# %%
# ------------------------------
# Gaussian + derivative fitting
# ------------------------------
def gaussian(x, A, x0, sigma, offset):
    return A * np.exp(-2 * ((x - x0)**2) / (sigma**2)) + offset

def derivative_gaussian(x, A, x0, sigma):
    return -(4 * A / sigma**2) * (x - x0) * np.exp(-2 * ((x - x0)**2) / (sigma**2))

# %%
# ------------------------------
# Arduino voltage reader
# ------------------------------
def read_arduino_voltage(arduino, n_samples=5):
    values = []
    for _ in range(n_samples):
        try:
            line = arduino.readline().decode().strip()
            if line:
                values.append(float(line))
        except:
            continue
    if values:
        return np.mean(values)
    return None

# %%
# ------------------------------
# Create range between two numbers with given steps
# ------------------------------
def create_range(start, stop, step):
    """
    Create a range of values from start to stop (inclusive) with step size.
    """
    
    return np.linspace(start, stop, int((stop-start)/step))

# %%
# ------------------------------
#Ell20/M Thorlabs Linear stage control + Analysis
# ------------------------------
def run_scan(stage_port="COM7", arduino_port="COM10"):
    # ---- Connect to Arduino ----
    print(f"Connecting to Arduino on {arduino_port}...")
    arduino = serial.Serial(arduino_port, 115200, timeout=1)
    time.sleep(2)  # allow Arduino reset

    # ---- Connect to Elliptec Stage ----
    print(f"Connecting to Elliptec stage on {stage_port}...")
    ctrl = elliptec.Controller(stage_port)
    stage = elliptec.Linear(ctrl)

    # Home stage
    print("Homing stage...")
    stage.home()
    time.sleep(1)

    # ---- Experiment Setup ----
    start_mm = 20.0  # start position in mm
    stop_mm  = 60.0  # stop position in mm
    step_mm  = 0.1   # step size in mm
    tia_gain = 1000  # V/A

    # Generate positions
    positions_mm = create_range(start_mm, stop_mm, step_mm)
    #positions_um = [int(p*1e3) for p in positions_mm]  # µm for stage control

    powers = []

    # ---- Step Scan ----
    for pos_um, pos_mm in zip(positions_mm, positions_mm):
        stage.set_distance(pos_um)
        time.sleep(0.2)

        voltage = read_arduino_voltage(arduino, n_samples=5)
        if voltage is None:
            continue

        photocurrent = voltage / tia_gain          # I = V/Rf
        laser_power = (photocurrent / 3.8e-3) * 10 # scale to 0–10 mW

        powers.append(laser_power)

        print(f"Pos={pos_mm:.3f} mm, V={voltage:.3f} V, P={laser_power:.3f} mW")

    return positions_mm, powers, arduino, ctrl

# %%
# ------------------------------
# Plot Knife Edge Power
# ------------------------------
def plot_power(positions, powers):
    plt.figure()
    plt.plot(positions, powers, 'bo-', label="Power vs Position")
    plt.xlabel("Knife Edge Position (mm)")
    plt.ylabel("Laser Power (mW)")
    plt.title("Knife Edge Scan")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
# ------------------------------
# Derivative + Gaussian Fit
# ------------------------------
def fit_derivative(positions, powers):
    positions = np.array(positions)
    powers = np.array(powers)

    # Numerical derivative
    deriv = np.gradient(powers, positions)

    # Gaussian fit
    popt, _ = curve_fit(gaussian, positions, powers,
                        p0=[max(powers), np.mean(positions), 2.0, min(powers)])
    fit_gaussian_vals = gaussian(positions, *popt)
    fit_deriv_vals = derivative_gaussian(positions, popt[0], popt[1], popt[2])

    # Beam waist (1/e^2 radius)
    w0 = popt[2] / np.sqrt(2)

    # Plot derivative
    plt.figure()
    plt.plot(positions, deriv, 'ro-', label="dP/dx (measured)")
    plt.plot(positions, fit_deriv_vals, 'b-', label="Gaussian fit derivative")
    plt.xlabel("Knife Edge Position (mm)")
    plt.ylabel("dP/dx (mW/mm)")
    plt.title("Beam Profile Derivative")
    plt.grid(True)
    plt.legend()
    plt.show()

    print(f"Estimated beam waist (1/e^2 radius): {w0*1e3:.2f} µm")

# %%
# ------------------------------
# Run the Knife Edge Scan
# ------------------------------
positions, powers, arduino, ctrl = run_scan(stage_port="COM7", arduino_port="COM10")
plot_power(positions, powers)
fit_derivative(positions, powers)

# Close connections
arduino.close()
ctrl.close()
# Out:
# Connecting to Arduino on COM10...
# Connecting to Elliptec stage on COM7...
# Controller on port COM7: Connection established!
# TX: b'0in'
# RX: b'0IN141200011620221401003C00000400\r\n'
# Status is a dictionary.
# Homing stage...
# TX: b'0ho0'
# RX: b'0POFFFFFFFB\r\n'
# Move Successful.
# TX: b'0ma00005000'
# RX: b'0PO00004FFE\r\n'
# Move Successful.
# Pos=20.000 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005066'
# RX: b'0PO00005061\r\n'
# Move Successful.
# Pos=20.100 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000050CD'
# RX: b'0PO000050CA\r\n'
# Move Successful.
# Pos=20.201 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005133'
# RX: b'0PO0000512F\r\n'
# Move Successful.
# Pos=20.301 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000519A'
# RX: b'0PO00005195\r\n'
# Move Successful.
# Pos=20.401 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005201'
# RX: b'0PO000051FD\r\n'
# Move Successful.
# Pos=20.501 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005267'
# RX: b'0PO00005262\r\n'
# Move Successful.
# Pos=20.602 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000052CE'
# RX: b'0PO000052CB\r\n'
# Move Successful.
# Pos=20.702 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005335'
# RX: b'0PO00005331\r\n'
# Move Successful.
# Pos=20.802 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000539B'
# RX: b'0PO00005397\r\n'
# Move Successful.
# Pos=20.902 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005402'
# RX: b'0PO000053FE\r\n'
# Move Successful.
# Pos=21.003 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005469'
# RX: b'0PO00005464\r\n'
# Move Successful.
# Pos=21.103 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000054CF'
# RX: b'0PO000054CB\r\n'
# Move Successful.
# Pos=21.203 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005536'
# RX: b'0PO00005531\r\n'
# Move Successful.
# Pos=21.303 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000559D'
# RX: b'0PO00005598\r\n'
# Move Successful.
# Pos=21.404 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005603'
# RX: b'0PO000055FF\r\n'
# Move Successful.
# Pos=21.504 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000566A'
# RX: b'0PO00005665\r\n'
# Move Successful.
# Pos=21.604 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000056D1'
# RX: b'0PO000056CC\r\n'
# Move Successful.
# Pos=21.704 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005737'
# RX: b'0PO00005733\r\n'
# Move Successful.
# Pos=21.805 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000579E'
# RX: b'0PO00005799\r\n'
# Move Successful.
# Pos=21.905 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005805'
# RX: b'0PO00005800\r\n'
# Move Successful.
# Pos=22.005 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000586B'
# RX: b'0PO00005866\r\n'
# Move Successful.
# Pos=22.105 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000058D2'
# RX: b'0PO000058CE\r\n'
# Move Successful.
# Pos=22.206 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005939'
# RX: b'0PO00005934\r\n'
# Move Successful.
# Pos=22.306 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000599F'
# RX: b'0PO0000599B\r\n'
# Move Successful.
# Pos=22.406 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005A06'
# RX: b'0PO00005A01\r\n'
# Move Successful.
# Pos=22.506 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005A6D'
# RX: b'0PO00005A69\r\n'
# Move Successful.
# Pos=22.607 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005AD3'
# RX: b'0PO00005ACE\r\n'
# Move Successful.
# Pos=22.707 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005B3A'
# RX: b'0PO00005B35\r\n'
# Move Successful.
# Pos=22.807 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00005BA1'
# RX: b'0PO00005B9D\r\n'
# Move Successful.
# Pos=22.907 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005C07'
# RX: b'0PO00005C02\r\n'
# Move Successful.
# Pos=23.008 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005C6E'
# RX: b'0PO00005C6A\r\n'
# Move Successful.
# Pos=23.108 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005CD5'
# RX: b'0PO00005CD0\r\n'
# Move Successful.
# Pos=23.208 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005D3B'
# RX: b'0PO00005D36\r\n'
# Move Successful.
# Pos=23.308 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005DA2'
# RX: b'0PO00005D9D\r\n'
# Move Successful.
# Pos=23.409 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005E08'
# RX: b'0PO00005E03\r\n'
# Move Successful.
# Pos=23.509 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005E6F'
# RX: b'0PO00005E6A\r\n'
# Move Successful.
# Pos=23.609 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005ED6'
# RX: b'0PO00005ED1\r\n'
# Move Successful.
# Pos=23.709 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005F3C'
# RX: b'0PO00005F37\r\n'
# Move Successful.
# Pos=23.810 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00005FA3'
# RX: b'0PO00005F9F\r\n'
# Move Successful.
# Pos=23.910 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000600A'
# RX: b'0PO00006005\r\n'
# Move Successful.
# Pos=24.010 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006070'
# RX: b'0PO0000606A\r\n'
# Move Successful.
# Pos=24.110 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000060D7'
# RX: b'0PO000060D3\r\n'
# Move Successful.
# Pos=24.211 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000613E'
# RX: b'0PO0000613A\r\n'
# Move Successful.
# Pos=24.311 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000061A4'
# RX: b'0PO000061A0\r\n'
# Move Successful.
# Pos=24.411 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000620B'
# RX: b'0PO00006206\r\n'
# Move Successful.
# Pos=24.511 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006272'
# RX: b'0PO0000626D\r\n'
# Move Successful.
# Pos=24.612 mm, V=4.882 V, P=12.847 mW
# TX: b'0ma000062D8'
# RX: b'0PO000062D4\r\n'
# Move Successful.
# Pos=24.712 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000633F'
# RX: b'0PO0000633A\r\n'
# Move Successful.
# Pos=24.812 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000063A6'
# RX: b'0PO000063A1\r\n'
# Move Successful.
# Pos=24.912 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000640C'
# RX: b'0PO00006407\r\n'
# Move Successful.
# Pos=25.013 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006473'
# RX: b'0PO0000646E\r\n'
# Move Successful.
# Pos=25.113 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000064DA'
# RX: b'0PO000064D5\r\n'
# Move Successful.
# Pos=25.213 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006540'
# RX: b'0PO0000653C\r\n'
# Move Successful.
# Pos=25.313 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000065A7'
# RX: b'0PO000065A2\r\n'
# Move Successful.
# Pos=25.414 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000660E'
# RX: b'0PO00006609\r\n'
# Move Successful.
# Pos=25.514 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006674'
# RX: b'0PO0000666F\r\n'
# Move Successful.
# Pos=25.614 mm, V=4.886 V, P=12.857 mW
# TX: b'0ma000066DB'
# RX: b'0PO000066D6\r\n'
# Move Successful.
# Pos=25.714 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006742'
# RX: b'0PO0000673D\r\n'
# Move Successful.
# Pos=25.815 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000067A8'
# RX: b'0PO000067A3\r\n'
# Move Successful.
# Pos=25.915 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000680F'
# RX: b'0PO0000680A\r\n'
# Move Successful.
# Pos=26.015 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006876'
# RX: b'0PO00006871\r\n'
# Move Successful.
# Pos=26.115 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000068DC'
# RX: b'0PO000068D7\r\n'
# Move Successful.
# Pos=26.216 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006943'
# RX: b'0PO0000693E\r\n'
# Move Successful.
# Pos=26.316 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000069AA'
# RX: b'0PO000069A5\r\n'
# Move Successful.
# Pos=26.416 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006A10'
# RX: b'0PO00006A0B\r\n'
# Move Successful.
# Pos=26.516 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006A77'
# RX: b'0PO00006A73\r\n'
# Move Successful.
# Pos=26.617 mm, V=4.882 V, P=12.847 mW
# TX: b'0ma00006ADD'
# RX: b'0PO00006AD8\r\n'
# Move Successful.
# Pos=26.717 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006B44'
# RX: b'0PO00006B3E\r\n'
# Move Successful.
# Pos=26.817 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006BAB'
# RX: b'0PO00006BA6\r\n'
# Move Successful.
# Pos=26.917 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006C11'
# RX: b'0PO00006C0C\r\n'
# Move Successful.
# Pos=27.018 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006C78'
# RX: b'0PO00006C73\r\n'
# Move Successful.
# Pos=27.118 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00006CDF'
# RX: b'0PO00006CDC\r\n'
# Move Successful.
# Pos=27.218 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006D45'
# RX: b'0PO00006D40\r\n'
# Move Successful.
# Pos=27.318 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006DAC'
# RX: b'0PO00006DA7\r\n'
# Move Successful.
# Pos=27.419 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006E13'
# RX: b'0PO00006E0E\r\n'
# Move Successful.
# Pos=27.519 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006E79'
# RX: b'0PO00006E74\r\n'
# Move Successful.
# Pos=27.619 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006EE0'
# RX: b'0PO00006EDB\r\n'
# Move Successful.
# Pos=27.719 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006F47'
# RX: b'0PO00006F42\r\n'
# Move Successful.
# Pos=27.820 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00006FAD'
# RX: b'0PO00006FA9\r\n'
# Move Successful.
# Pos=27.920 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00007014'
# RX: b'0PO0000700F\r\n'
# Move Successful.
# Pos=28.020 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000707B'
# RX: b'0PO00007076\r\n'
# Move Successful.
# Pos=28.120 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000070E1'
# RX: b'0PO000070DC\r\n'
# Move Successful.
# Pos=28.221 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007148'
# RX: b'0PO00007143\r\n'
# Move Successful.
# Pos=28.321 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma000071AF'
# RX: b'0PO000071AD\r\n'
# Move Successful.
# Pos=28.421 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007215'
# RX: b'0PO00007212\r\n'
# Move Successful.
# Pos=28.521 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000727C'
# RX: b'0PO00007277\r\n'
# Move Successful.
# Pos=28.622 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000072E3'
# RX: b'0PO000072DF\r\n'
# Move Successful.
# Pos=28.722 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007349'
# RX: b'0PO00007344\r\n'
# Move Successful.
# Pos=28.822 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000073B0'
# RX: b'0PO000073AB\r\n'
# Move Successful.
# Pos=28.922 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007417'
# RX: b'0PO00007412\r\n'
# Move Successful.
# Pos=29.023 mm, V=4.882 V, P=12.847 mW
# TX: b'0ma0000747D'
# RX: b'0PO00007478\r\n'
# Move Successful.
# Pos=29.123 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000074E4'
# RX: b'0PO000074DF\r\n'
# Move Successful.
# Pos=29.223 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000754B'
# RX: b'0PO00007546\r\n'
# Move Successful.
# Pos=29.323 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000075B1'
# RX: b'0PO000075AC\r\n'
# Move Successful.
# Pos=29.424 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00007618'
# RX: b'0PO00007612\r\n'
# Move Successful.
# Pos=29.524 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000767F'
# RX: b'0PO00007679\r\n'
# Move Successful.
# Pos=29.624 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000076E5'
# RX: b'0PO000076E0\r\n'
# Move Successful.
# Pos=29.724 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000774C'
# RX: b'0PO00007746\r\n'
# Move Successful.
# Pos=29.825 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000077B3'
# RX: b'0PO000077AE\r\n'
# Move Successful.
# Pos=29.925 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007819'
# RX: b'0PO00007816\r\n'
# Move Successful.
# Pos=30.025 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007880'
# RX: b'0PO0000787D\r\n'
# Move Successful.
# Pos=30.125 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma000078E6'
# RX: b'0PO000078E1\r\n'
# Move Successful.
# Pos=30.226 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000794D'
# RX: b'0PO00007949\r\n'
# Move Successful.
# Pos=30.326 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000079B4'
# RX: b'0PO000079B0\r\n'
# Move Successful.
# Pos=30.426 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007A1A'
# RX: b'0PO00007A14\r\n'
# Move Successful.
# Pos=30.526 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007A81'
# RX: b'0PO00007A7C\r\n'
# Move Successful.
# Pos=30.627 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00007AE8'
# RX: b'0PO00007AE2\r\n'
# Move Successful.
# Pos=30.727 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007B4E'
# RX: b'0PO00007B49\r\n'
# Move Successful.
# Pos=30.827 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007BB5'
# RX: b'0PO00007BB0\r\n'
# Move Successful.
# Pos=30.927 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007C1C'
# RX: b'0PO00007C19\r\n'
# Move Successful.
# Pos=31.028 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007C82'
# RX: b'0PO00007C7E\r\n'
# Move Successful.
# Pos=31.128 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007CE9'
# RX: b'0PO00007CE4\r\n'
# Move Successful.
# Pos=31.228 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007D50'
# RX: b'0PO00007D4B\r\n'
# Move Successful.
# Pos=31.328 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007DB6'
# RX: b'0PO00007DB2\r\n'
# Move Successful.
# Pos=31.429 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007E1D'
# RX: b'0PO00007E18\r\n'
# Move Successful.
# Pos=31.529 mm, V=4.882 V, P=12.847 mW
# TX: b'0ma00007E84'
# RX: b'0PO00007E80\r\n'
# Move Successful.
# Pos=31.629 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00007EEA'
# RX: b'0PO00007EE6\r\n'
# Move Successful.
# Pos=31.729 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00007F51'
# RX: b'0PO00007F4C\r\n'
# Move Successful.
# Pos=31.830 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00007FB8'
# RX: b'0PO00007FB3\r\n'
# Move Successful.
# Pos=31.930 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000801E'
# RX: b'0PO00008019\r\n'
# Move Successful.
# Pos=32.030 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008085'
# RX: b'0PO00008080\r\n'
# Move Successful.
# Pos=32.130 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000080EC'
# RX: b'0PO000080E7\r\n'
# Move Successful.
# Pos=32.231 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008152'
# RX: b'0PO0000814D\r\n'
# Move Successful.
# Pos=32.331 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000081B9'
# RX: b'0PO000081B5\r\n'
# Move Successful.
# Pos=32.431 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008220'
# RX: b'0PO0000821C\r\n'
# Move Successful.
# Pos=32.531 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008286'
# RX: b'0PO00008281\r\n'
# Move Successful.
# Pos=32.632 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000082ED'
# RX: b'0PO000082E8\r\n'
# Move Successful.
# Pos=32.732 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008354'
# RX: b'0PO00008351\r\n'
# Move Successful.
# Pos=32.832 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000083BA'
# RX: b'0PO000083B6\r\n'
# Move Successful.
# Pos=32.932 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008421'
# RX: b'0PO0000841C\r\n'
# Move Successful.
# Pos=33.033 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008488'
# RX: b'0PO00008483\r\n'
# Move Successful.
# Pos=33.133 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000084EE'
# RX: b'0PO000084ED\r\n'
# Move Successful.
# Pos=33.233 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008555'
# RX: b'0PO00008550\r\n'
# Move Successful.
# Pos=33.333 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000085BB'
# RX: b'0PO000085B6\r\n'
# Move Successful.
# Pos=33.434 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008622'
# RX: b'0PO0000861E\r\n'
# Move Successful.
# Pos=33.534 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008689'
# RX: b'0PO00008684\r\n'
# Move Successful.
# Pos=33.634 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000086EF'
# RX: b'0PO000086EA\r\n'
# Move Successful.
# Pos=33.734 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008756'
# RX: b'0PO00008751\r\n'
# Move Successful.
# Pos=33.835 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000087BD'
# RX: b'0PO000087B9\r\n'
# Move Successful.
# Pos=33.935 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma00008823'
# RX: b'0PO0000881E\r\n'
# Move Successful.
# Pos=34.035 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000888A'
# RX: b'0PO00008885\r\n'
# Move Successful.
# Pos=34.135 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma000088F1'
# RX: b'0PO000088ED\r\n'
# Move Successful.
# Pos=34.236 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008957'
# RX: b'0PO00008952\r\n'
# Move Successful.
# Pos=34.336 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000089BE'
# RX: b'0PO000089B9\r\n'
# Move Successful.
# Pos=34.436 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008A25'
# RX: b'0PO00008A20\r\n'
# Move Successful.
# Pos=34.536 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008A8B'
# RX: b'0PO00008A88\r\n'
# Move Successful.
# Pos=34.637 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma00008AF2'
# RX: b'0PO00008AED\r\n'
# Move Successful.
# Pos=34.737 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008B59'
# RX: b'0PO00008B54\r\n'
# Move Successful.
# Pos=34.837 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008BBF'
# RX: b'0PO00008BBA\r\n'
# Move Successful.
# Pos=34.937 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008C26'
# RX: b'0PO00008C22\r\n'
# Move Successful.
# Pos=35.038 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008C8D'
# RX: b'0PO00008C89\r\n'
# Move Successful.
# Pos=35.138 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008CF3'
# RX: b'0PO00008CF0\r\n'
# Move Successful.
# Pos=35.238 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008D5A'
# RX: b'0PO00008D55\r\n'
# Move Successful.
# Pos=35.338 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008DC1'
# RX: b'0PO00008DBC\r\n'
# Move Successful.
# Pos=35.439 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008E27'
# RX: b'0PO00008E22\r\n'
# Move Successful.
# Pos=35.539 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008E8E'
# RX: b'0PO00008E8B\r\n'
# Move Successful.
# Pos=35.639 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00008EF5'
# RX: b'0PO00008EF0\r\n'
# Move Successful.
# Pos=35.739 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008F5B'
# RX: b'0PO00008F56\r\n'
# Move Successful.
# Pos=35.840 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00008FC2'
# RX: b'0PO00008FBC\r\n'
# Move Successful.
# Pos=35.940 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009029'
# RX: b'0PO00009024\r\n'
# Move Successful.
# Pos=36.040 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000908F'
# RX: b'0PO0000908A\r\n'
# Move Successful.
# Pos=36.140 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma000090F6'
# RX: b'0PO000090F1\r\n'
# Move Successful.
# Pos=36.241 mm, V=4.886 V, P=12.857 mW
# TX: b'0ma0000915D'
# RX: b'0PO00009158\r\n'
# Move Successful.
# Pos=36.341 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000091C3'
# RX: b'0PO000091BE\r\n'
# Move Successful.
# Pos=36.441 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000922A'
# RX: b'0PO00009225\r\n'
# Move Successful.
# Pos=36.541 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009291'
# RX: b'0PO0000928C\r\n'
# Move Successful.
# Pos=36.642 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000092F7'
# RX: b'0PO000092F2\r\n'
# Move Successful.
# Pos=36.742 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000935E'
# RX: b'0PO00009359\r\n'
# Move Successful.
# Pos=36.842 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000093C4'
# RX: b'0PO000093BE\r\n'
# Move Successful.
# Pos=36.942 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000942B'
# RX: b'0PO00009426\r\n'
# Move Successful.
# Pos=37.043 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009492'
# RX: b'0PO0000948E\r\n'
# Move Successful.
# Pos=37.143 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000094F8'
# RX: b'0PO000094F7\r\n'
# Move Successful.
# Pos=37.243 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000955F'
# RX: b'0PO0000955B\r\n'
# Move Successful.
# Pos=37.343 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000095C6'
# RX: b'0PO000095C1\r\n'
# Move Successful.
# Pos=37.444 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000962C'
# RX: b'0PO00009630\r\n'
# Move Successful.
# Pos=37.544 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009693'
# RX: b'0PO0000968F\r\n'
# Move Successful.
# Pos=37.644 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma000096FA'
# RX: b'0PO000096F5\r\n'
# Move Successful.
# Pos=37.744 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009760'
# RX: b'0PO0000975C\r\n'
# Move Successful.
# Pos=37.845 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000097C7'
# RX: b'0PO000097C4\r\n'
# Move Successful.
# Pos=37.945 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000982E'
# RX: b'0PO0000982A\r\n'
# Move Successful.
# Pos=38.045 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma00009894'
# RX: b'0PO00009891\r\n'
# Move Successful.
# Pos=38.145 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma000098FB'
# RX: b'0PO000098F8\r\n'
# Move Successful.
# Pos=38.246 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009962'
# RX: b'0PO00009960\r\n'
# Move Successful.
# Pos=38.346 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma000099C8'
# RX: b'0PO000099C6\r\n'
# Move Successful.
# Pos=38.446 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009A2F'
# RX: b'0PO00009A2A\r\n'
# Move Successful.
# Pos=38.546 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009A96'
# RX: b'0PO00009A91\r\n'
# Move Successful.
# Pos=38.647 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009AFC'
# RX: b'0PO00009AF6\r\n'
# Move Successful.
# Pos=38.747 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009B63'
# RX: b'0PO00009B5D\r\n'
# Move Successful.
# Pos=38.847 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009BCA'
# RX: b'0PO00009BC7\r\n'
# Move Successful.
# Pos=38.947 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009C30'
# RX: b'0PO00009C2B\r\n'
# Move Successful.
# Pos=39.048 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009C97'
# RX: b'0PO00009C92\r\n'
# Move Successful.
# Pos=39.148 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009CFE'
# RX: b'0PO00009CF9\r\n'
# Move Successful.
# Pos=39.248 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009D64'
# RX: b'0PO00009D5F\r\n'
# Move Successful.
# Pos=39.348 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009DCB'
# RX: b'0PO00009DC6\r\n'
# Move Successful.
# Pos=39.449 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma00009E32'
# RX: b'0PO00009E2E\r\n'
# Move Successful.
# Pos=39.549 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009E98'
# RX: b'0PO00009E93\r\n'
# Move Successful.
# Pos=39.649 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009EFF'
# RX: b'0PO00009EFA\r\n'
# Move Successful.
# Pos=39.749 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma00009F66'
# RX: b'0PO00009F61\r\n'
# Move Successful.
# Pos=39.850 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma00009FCC'
# RX: b'0PO00009FC7\r\n'
# Move Successful.
# Pos=39.950 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A033'
# RX: b'0PO0000A031\r\n'
# Move Successful.
# Pos=40.050 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A099'
# RX: b'0PO0000A094\r\n'
# Move Successful.
# Pos=40.150 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A100'
# RX: b'0PO0000A0FC\r\n'
# Move Successful.
# Pos=40.251 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A167'
# RX: b'0PO0000A162\r\n'
# Move Successful.
# Pos=40.351 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A1CD'
# RX: b'0PO0000A1CD\r\n'
# Move Successful.
# Pos=40.451 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A234'
# RX: b'0PO0000A231\r\n'
# Move Successful.
# Pos=40.551 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000A29B'
# RX: b'0PO0000A296\r\n'
# Move Successful.
# Pos=40.652 mm, V=4.885 V, P=12.854 mW
# TX: b'0ma0000A301'
# RX: b'0PO0000A2FD\r\n'
# Move Successful.
# Pos=40.752 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A368'
# RX: b'0PO0000A366\r\n'
# Move Successful.
# Pos=40.852 mm, V=4.884 V, P=12.852 mW
# TX: b'0ma0000A3CF'
# RX: b'0PO0000A3CB\r\n'
# Move Successful.
# Pos=40.952 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A435'
# RX: b'0PO0000A432\r\n'
# Move Successful.
# Pos=41.053 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A49C'
# RX: b'0PO0000A497\r\n'
# Move Successful.
# Pos=41.153 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A503'
# RX: b'0PO0000A4FE\r\n'
# Move Successful.
# Pos=41.253 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A569'
# RX: b'0PO0000A565\r\n'
# Move Successful.
# Pos=41.353 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A5D0'
# RX: b'0PO0000A5CB\r\n'
# Move Successful.
# Pos=41.454 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A637'
# RX: b'0PO0000A632\r\n'
# Move Successful.
# Pos=41.554 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A69D'
# RX: b'0PO0000A698\r\n'
# Move Successful.
# Pos=41.654 mm, V=4.883 V, P=12.849 mW
# TX: b'0ma0000A704'
